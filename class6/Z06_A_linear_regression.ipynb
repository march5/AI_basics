# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import sklearn.linear_model as lm
from sklearn import datasets, linear_model
import matplotlib.pyplot as plt

# %% [markdown]
# Proszę narysować wykres dowolnej funkcji na odcinku $[0,3]$.
#
# Będzie to model, który będziemy chcieli znaleźć.

# %%
f = lambda x: ((x*2-1)*(x**2-2)*(x-2)+3)
x_tr = np.linspace(0, 3, 200)
y_tr = f(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_tr[:200], y_tr[:200], '--k');
plt.show()

# %% [markdown]
# Proszę wylosować kilka punktów z otoczenia funkcji $f(x)$ .
#
# Na ich podstawie będziemy wykonywać naszej presykcji.

# %%
x = stats.uniform(0,3).rvs(100)
y = f(x) + stats.norm(0,0.2).rvs(len(x))
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_tr, y_tr, '--k');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# Nauczmy prosty model regresji liniowej
#
# $y = a ⋅ x + b$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji. My narazie urzyjemy metody opartej na rozwiązaniu układu równań liniowych.

# %%
x=np.vstack(x)
model1 = linear_model.LinearRegression()
model1.fit(x, y)

# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

print(model1.coef_)
print(model1.intercept_)
print(model1.score(x,y))
# Out:
# [5.90666936]
# -2.731324459466494
# 0.5163097879466472

# %%
# Plot outputs
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.scatter(x, y,  color='black')
plt.plot(x, model1.predict(x), color='blue',linewidth=3)
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $y = a_1 ⋅ x + a_2 ⋅ x^2 + b$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline

# %%
model2 = make_pipeline(PolynomialFeatures(2), linear_model.LinearRegression())
model2.fit(x, y)
# Out:
# Pipeline(steps=[('polynomialfeatures', PolynomialFeatures()),
#                 ('linearregression', LinearRegression())])

# %%
# Plot outputs
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.scatter(x, y,  color='black')
x_plot = np.vstack(np.linspace(0, 10, 100))
plt.plot(x_plot, model2.predict(x_plot), color='blue',linewidth=3)
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $y = a_1 ⋅ x + a_2 ⋅ x^2 + a_3 ⋅ x^3 + b$
#
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
model3 = make_pipeline(PolynomialFeatures(3), linear_model.LinearRegression())
model3.fit(x, y)
# Out:
# Pipeline(steps=[('polynomialfeatures', PolynomialFeatures(degree=3)),
#                 ('linearregression', LinearRegression())])

# %%
# Plot outputs
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.scatter(x, y,  color='black')
x_plot = np.vstack(np.linspace(0, 10, 100))
plt.plot(x_plot, model3.predict(x_plot), color='green',linewidth=3)
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $y = a_1 ⋅ x + a_2 ⋅ x^2 + a_3 ⋅ x^3 + a_4 ⋅ x^4 + b$
#
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
model4 = make_pipeline(PolynomialFeatures(4), linear_model.LinearRegression())
model4.fit(x, y)

# Plot outputs
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.scatter(x, y,  color='black')
x_plot = np.vstack(np.linspace(0, 10, 100))
plt.plot(x_plot, model4.predict(x_plot), color='yellow',linewidth=3)
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $y = a_1 ⋅ x + a_2 ⋅ x^2 + a_3 ⋅ x^3 + a_4 ⋅ x^4 + a_5 ⋅ x^5 + b$
#
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
model5 = make_pipeline(PolynomialFeatures(5), linear_model.LinearRegression())
model5.fit(x, y)

# Plot outputs
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.scatter(x, y,  color='black')
x_plot = np.vstack(np.linspace(0, 10, 100))
plt.plot(x_plot, model5.predict(x_plot), color='red',linewidth=3)
plt.show()

# %% [markdown]
# # Zadanie
# Narysuj wszystkie wyniki na jednym wykresie.

# %%
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.scatter(x, y,  color='black')
x_plot = np.vstack(np.linspace(0, 10, 100))
plt.plot(x_plot, model1.predict(x_plot), color='blue',linewidth=2)
plt.plot(x_plot, model2.predict(x_plot), color='magenta',linewidth=2)
plt.plot(x_plot, model3.predict(x_plot), color='green',linewidth=2)
plt.plot(x_plot, model4.predict(x_plot), color='yellow',linewidth=2)
plt.plot(x_plot, model5.predict(x_plot), color='red',linewidth=2)
plt.show()

# %% [markdown]
# # Zadanie
# Musimy mieć jakąś miarę oceny.

# %%
from sklearn import  metrics

error1 = np.average( np.abs(model1.predict(x) -y) )
print("Mean absolute errors: {}".format(error1))
print("Mean absolute errors: {}".format(metrics.mean_absolute_error(y, model1.predict(x))))

error2 = np.average( (model1.predict(x) -y) **2 )
print("Mean squared error: {}".format(error2))
print("Mean squared error: {}".format( metrics.mean_squared_error(y, model1.predict(x)) ))

error3 = np.median( np.abs(model1.predict(x) -y) )
print("Median absolute error: {}".format( error3 ))
print("Median absolute error: {}".format( metrics.median_absolute_error(y, model1.predict(x)) ))

print("R^2: {}".format(metrics.r2_score(y, model1.predict(x))))
ss_res=np.sum( (y-model1.predict(x))**2 )
ss_tot=np.sum( (y-np.mean(y))**2 )
R=1-ss_res/ss_tot
print("R^2: {}".format(R))

error4 = 1-np.var(y - model1.predict(x) )/np.var(y)
print("Explained variance score: {}".format( error4 ))
print("Explained variance score: {}".format( metrics.explained_variance_score(y, model1.predict(x)) ))
# Out:
# Mean absolute errors: 3.709988081754259
# Mean absolute errors: 3.709988081754259
# Mean squared error: 23.641959354525394
# Mean squared error: 23.641959354525394
# Median absolute error: 2.679898010018535
# Median absolute error: 2.679898010018535
# R^2: 0.5163097879466472
# R^2: 0.5163097879466472
# Explained variance score: 0.5163097879466472
# Explained variance score: 0.5163097879466472

# %% [markdown]
# # Zadanie
# Wylicz powyższe miary dla wszytkich modeli.

# %%
#model1
print("model1")
error4 = 1-np.var(y - model1.predict(x) )/np.var(y)
print("Explained variance score: {}".format( error4 ))
error3 = np.median( np.abs(model1.predict(x) -y) )
print("Median absolute error: {}".format( error3 ))
error2 = np.average( (model1.predict(x) -y) **2 )
print("Mean squared error: {}".format(error2))
error1 = np.average( np.abs(model1.predict(x) -y) )
print("Mean absolute errors: {}".format(error1))

#model2
print("model1")
error4 = 1-np.var(y - model2.predict(x) )/np.var(y)
print("Explained variance score: {}".format( error4 ))
error3 = np.median( np.abs(model2.predict(x) -y) )
print("Median absolute error: {}".format( error3 ))
error2 = np.average( (model2.predict(x) -y) **2 )
print("Mean squared error: {}".format(error2))
error1 = np.average( np.abs(model2.predict(x) -y) )
print("Mean absolute errors: {}".format(error1))

#model3
print("model1")
error4 = 1-np.var(y - model3.predict(x) )/np.var(y)
print("Explained variance score: {}".format( error4 ))
error3 = np.median( np.abs(model3.predict(x) -y) )
print("Median absolute error: {}".format( error3 ))
error2 = np.average( (model3.predict(x) -y) **2 )
print("Mean squared error: {}".format(error2))
error1 = np.average( np.abs(model3.predict(x) -y) )
print("Mean absolute errors: {}".format(error1))

#model4
print("model1")
error4 = 1-np.var(y - model4.predict(x) )/np.var(y)
print("Explained variance score: {}".format( error4 ))
error3 = np.median( np.abs(model4.predict(x) -y) )
print("Median absolute error: {}".format( error3 ))
error2 = np.average( (model4.predict(x) -y) **2 )
print("Mean squared error: {}".format(error2))
error1 = np.average( np.abs(model4.predict(x) -y) )
print("Mean absolute errors: {}".format(error1))

#model5
print("model1")
error4 = 1-np.var(y - model5.predict(x) )/np.var(y)
print("Explained variance score: {}".format( error4 ))
error3 = np.median( np.abs(model5.predict(x) -y) )
print("Median absolute error: {}".format( error3 ))
error2 = np.average( (model5.predict(x) -y) **2 )
print("Mean squared error: {}".format(error2))
error1 = np.average( np.abs(model5.predict(x) -y) )
print("Mean absolute errors: {}".format(error1))
# Out:
# model1
# Explained variance score: 0.5163097879466472
# Median absolute error: 2.679898010018535
# Mean squared error: 23.641959354525394
# Mean absolute errors: 3.709988081754259
# model1
# Explained variance score: 0.785930451437515
# Median absolute error: 2.6793403157715936
# Mean squared error: 10.46335741356209
# Mean absolute errors: 2.7191091551444786
# model1
# Explained variance score: 0.9898365865509383
# Median absolute error: 0.5847413907303556
# Mean squared error: 0.49677045695406635
# Mean absolute errors: 0.593322181365542
# model1
# Explained variance score: 0.9993888466089592
# Median absolute error: 0.10817212115285035
# Mean squared error: 0.029872143926646274
# Mean absolute errors: 0.13629963758772934
# model1
# Explained variance score: 0.9993888466089592
# Median absolute error: 0.10817212115285035
# Mean squared error: 0.029872143926646274
# Mean absolute errors: 0.13629963758772934
